# %% [markdown]
# # NIDS Project — Quick Preview (Colab)
#
# This notebook runs a fast preview of the training pipeline on Google Colab.
# Instructions:
# 1. Upload the `data/raw/` CSVs into `/content/nids-data/` or mount Google Drive and place them under `MyDrive/nids-data/data/raw/`.
# 2. If you have a Git remote for this repo, use the `git clone` cell; otherwise upload the project files as a zip and unzip into `/content/nids-project`.
# 3. Run the cells in order. The preview will run a 3-fold CV with fewer features to be fast.

# %%
# Option A: mount Google Drive (recommended if dataset is large)
from google.colab import drive
drive.mount('/content/drive')
# After mounting, copy or symlink your data into /content/nids-data/ or into the repo path you use below.

# %%
# Option B: clone repo (if available)
# Replace <GIT_REPO_URL> with your repository URL if you have one
# !git clone <GIT_REPO_URL> nids-project || true
# %cd nids-project
# Install requirements
# !pip install -r requirements.txt --quiet

# %%
# If you don't have a git remote, upload a zip of the project and unzip here:
# from google.colab import files
# uploaded = files.upload()
# !unzip uploaded_file.zip -d /content/nids-project

# %%
# Run a quick preview (3-fold CV, top 10 features). Adjust paths if your data is elsewhere.
# %cd nids-project
# !python -m src.train --data_dir data/raw/ --top_n_features 10 --cv_folds 3 --cv_jobs -1

# %% [markdown]
# ## Notes
# - Use `--cv_jobs -1` to use all CPU cores available in the Colab instance.
# - For larger experiments, consider using Colab Pro for more CPU/RAM.
